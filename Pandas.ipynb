# %%
import pandas as pd
import numpy as np

# %%
list=['rk','vk','sk','tk','lk']
s=pd.Series(list,index=['A','B','C','D','E'])
print(s)
# Out:
# A    rk
# B    vk
# C    sk
# D    tk
# E    lk
# dtype: object

# %%
d={
    "RollNo":[1,2,3,4,5,6,7],
    "name":["rk","vk","sk","ak","dk","al","gk"],
    "marks":[56,67,87,98,45,67,88],
    "Branch":["cs","cs","DS","DS","cs","DS","DS"]
}
print(d)
print(type(d))
df=pd.DataFrame(d,index=['A','B','C','D','E','F','G'])
print(df)
# Out:
# {'RollNo': [1, 2, 3, 4, 5, 6, 7], 'name': ['rk', 'vk', 'sk', 'ak', 'dk', 'al', 'gk'], 'marks': [56, 67, 87, 98, 45, 67, 88], 'Branch': ['cs', 'cs', 'DS', 'DS', 'cs', 'DS', 'DS']}
# <class 'dict'>
#    RollNo name  marks Branch
# A       1   rk     56     cs
# B       2   vk     67     cs
# C       3   sk     87     DS
# D       4   ak     98     DS
# E       5   dk     45     cs
# F       6   al     67     DS
# G       7   gk     88     DS

# %%
df = pd.read_csv("student.csv")
print(df)
# Out:
#              name                class                  subject  marks  gender
# 0    Rohan Sharma  B.Tech CSE 3rd Year      Database Management     69    Male
# 1     Rohan Kumar  B.Tech CSE 1st Year          Cloud Computing     82    Male
# 2    Khushi Verma  B.Tech CSE 2nd Year      Database Management     87    Male
# 3     Karan Gupta  B.Tech CSE 4th Year      Database Management     83  Female
# 4    Khushi Singh  B.Tech CSE 4th Year        Computer Networks     72    Male
# 5      Diya Patel  B.Tech CSE 1st Year               Algorithms     79    Male
# 6     Rahul Patel  B.Tech CSE 3rd Year          Data Structures     84    Male
# 7    Simran Verma  B.Tech CSE 3rd Year     Software Engineering     94  Female
# 8     Aditi Gupta  B.Tech CSE 1st Year          Data Structures     97    Male
# 9    Aditya Verma  B.Tech CSE 2nd Year               Algorithms     79  Female
# 10    Nisha Patel  B.Tech CSE 2nd Year        Computer Networks     77    Male
# ...

# %%
print(df[(df["marks"] > 80) & (df["class"] == "B.Tech CSE 1st Year")])
# Out:
#             name                class               subject  marks  gender
# 1    Rohan Kumar  B.Tech CSE 1st Year       Cloud Computing     82    Male
# 8    Aditi Gupta  B.Tech CSE 1st Year       Data Structures     97    Male
# 26     Kabir Roy  B.Tech CSE 1st Year            Algorithms     86    Male
# 40   Nisha Kumar  B.Tech CSE 1st Year       Data Structures     96    Male
# 45   Neha Sharma  B.Tech CSE 1st Year       Cloud Computing     85    Male
# 51     Nisha Roy  B.Tech CSE 1st Year            Algorithms     89    Male
# 54  Ritika Kumar  B.Tech CSE 1st Year  Software Engineering     90  Female

# %%
df = pd.read_excel("data.xlsx")
print(df)
print(df.head(9))
print(df.tail())
#single column

print(df['Subjects'])

#multiple columns
print(df["Gender"].head())
# Out:
#     Subjects  Marks  Gender
# 0       Math     88  Female
# 1    Science     92    Male
# 2    English     76  Female
# 3   Computer     95    Male
# 4    Physics     81  Female
# 5  Chemistry     89    Male
# 6    Biology     74  Female
# 7    History     85    Male
# 8  Geography     90  Female
# 9  Economics     78    Male
#     Subjects  Marks  Gender
# 0       Math     88  Female
# 1    Science     92    Male
# 2    English     76  Female
# 3   Computer     95    Male
# 4    Physics     81  Female
# 5  Chemistry     89    Male
# 6    Biology     74  Female
# 7    History     85    Male
# 8  Geography     90  Female
#     Subjects  Marks  Gender
# 5  Chemistry     89    Male
# 6    Biology     74  Female
# 7    History     85    Male
# 8  Geography     90  Female
# 9  Economics     78    Male
# 0         Math
# 1      Science
# 2      English
# 3     Computer
# 4      Physics
# 5    Chemistry
# 6      Biology
# 7      History
# 8    Geography
# 9    Economics
# ...

# %%
df.describe()
# Out:
#            Marks
# count  10.000000
# mean   84.800000
# std     7.192589
# min    74.000000
# 25%    78.750000
# 50%    86.500000
# 75%    89.750000
# max    95.000000

# %%
df.shape
# Out:
# (10, 3)

# %%
print(df[['Subjects','Marks','Gender']])
# Out:
#     Subjects  Marks  Gender
# 0       Math     88  Female
# 1    Science     92    Male
# 2    English     76  Female
# 3   Computer     95    Male
# 4    Physics     81  Female
# 5  Chemistry     89    Male
# 6    Biology     74  Female
# 7    History     85    Male
# 8  Geography     90  Female
# 9  Economics     78    Male

# %%
print(df)


print(df.loc[4])
# Out:
#     Subjects  Marks  Gender
# 0       Math     88  Female
# 1    Science     92    Male
# 2    English     76  Female
# 3   Computer     95    Male
# 4    Physics     81  Female
# 5  Chemistry     89    Male
# 6    Biology     74  Female
# 7    History     85    Male
# 8  Geography     90  Female
# 9  Economics     78    Male
# Subjects    Physics
# Marks            81
# Gender       Female
# Name: 4, dtype: object

# %%
print(df[df["Marks"] > 80])
# Out:
#     Subjects  Marks  Gender
# 0       Math     88  Female
# 1    Science     92    Male
# 3   Computer     95    Male
# 4    Physics     81  Female
# 5  Chemistry     89    Male
# 7    History     85    Male
# 8  Geography     90  Female

# %%
df = pd.read_csv("student_dataset.csv")
print(df)
# Out:
#    RollNo   Name  Age    City  Marks
# 0     101   Amit   20   Delhi     85
# 1     102  Priya   21  Mumbai     90
# 2     103  Rahul   19    Pune     78
# 3     104  Sneha   22   Delhi     88
# 4     105  Karan   20  Jaipur     76

# %%
print(df.head(3))
# Out:
#    RollNo   Name  Age    City  Marks
# 0     101   Amit   20   Delhi     85
# 1     102  Priya   21  Mumbai     90
# 2     103  Rahul   19    Pune     78

# %%
print(df.tail(2))
# Out:
#    RollNo   Name  Age    City  Marks
# 3     104  Sneha   22   Delhi     88
# 4     105  Karan   20  Jaipur     76

# %%
print(df['Name'])
# Out:
# 0     Amit
# 1    Priya
# 2    Rahul
# 3    Sneha
# 4    Karan
# Name: Name, dtype: object

# %%
print(df[['Name','Marks']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df[['Name','Marks']])
#
# NameError: name 'df' is not defined
