# %%
marks=[75,65,38,95,82,96,36,99,80,85]
print(marks)
print("Total Marks:",sum(marks))
print("Average Marks:",sum(marks)/10)
print("Highest Marks:",max(marks))
print("Lowest Marks:",min(marks))
#students  who scored above 75
count=0
for i in marks:
    if i> 75:
        count+=1
        print("Students who scored marks above 75:",count)

#who failed
fail=0
for i in marks:
    if i<40:
        fail+=1
        print("Students who are fail:",fail)


#search for a particular marks
print(marks[3])

#Sort marks in ascending order
print("Ascending Order:",sorted(marks))

#Sort marks in Descending Order
print("Descending Order:",sorted(marks)[::-1])

#Display even number
for i in marks:
    if i%2==0:
        print("even:",i)

#Replace the specific marks
# Out:
# [75, 65, 38, 95, 82, 96, 36, 99, 80, 85]
# Total Marks: 751
# Average Marks: 75.1
# Highest Marks: 99
# Lowest Marks: 36
# Students who scored marks above 75: 1
# Students who scored marks above 75: 2
# Students who scored marks above 75: 3
# Students who scored marks above 75: 4
# Students who scored marks above 75: 5
# Students who scored marks above 75: 6
# Students who are fail: 1
# Students who are fail: 2
# 95
# Ascending Order: [36, 38, 65, 75, 80, 82, 85, 95, 96, 99]
# Descending Order: [99, 96, 95, 85, 82, 80, 75, 65, 38, 36]
# even: 38
# even: 82
# even: 96
# even: 36
# even: 80

# %%
# University Management System

class University:
    def __init__(self, University_Name, University_Location):
        self.University_Name= University_Name
        self.University_Location= University_Location
        
    class Department(University):
        def __init__(self, University_Name, University_Location, Department_Name, HOD_Name):
            self.University_Name= University_Name
            self.University_Location= University_Location
            self.Department_Name= Department_Name
            self.HOD_Name= HOD_Name
        Department(University)

    class Student(Department):
        def __init__(self, University_Name, University_Location, Department_Name, HOD_Name, student_name, roll_No, Semester,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # University Management System
# ----> 3 class University:
#       4     def __init__(self, University_Name, University_Location):
#       5         self.University_Name= University_Name
#
# Cell In[35], line 8, in University()
#       5     self.University_Name= University_Name
#       6     self.University_Location= University_Location
# ----> 8 class Department(University):
#       9     def __init__(self, University_Name, University_Location, Department_Name, HOD_Name):
#      10         self.University_Name= University_Name
#
# NameError: name 'University' is not defined
